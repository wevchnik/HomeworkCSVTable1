# %% [markdown]
# ## Подготовка

# %%
import numpy as numpy
import pandas as pandas

# %%
table = pandas.read_csv('train.csv')

# %%
table
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Задание 1
#
# Выведите размер таблицы

# %%
'{0}x{1}'.format(len(table), len(table.columns))
# Out:
# '891x12'

# %% [markdown]
# ## Задание 2
#
# Выведите первые 5 строк

# %%
table.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Задание 3
#
# Выведите последние 5 строк

# %%
table.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## Задание 4
#
# Выведите случайные 10 строк

# %%
table.sample(10)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 274          275         1       3    Healy, Miss. Hanora "Nora"  female
# 86            87         0       3        Ford, Mr. William Neal    male
# 681          682         1       1            Hassab, Mr. Hammad    male
# 847          848         0       3            Markoff, Mr. Marin    male
# 47            48         1       3     O'Driscoll, Miss. Bridget  female
# 547          548         1       2    Padro y Manent, Mr. Julian    male
# 798          799         0       3  Ibrahim Shawah, Mr. Yousseff    male
# 80            81         0       3          Waelens, Mr. Achille    male
# 221          222         0       2          Bracken, Mr. James H    male
# 51            52         0       3  Nosworthy, Mr. Richard Cater    male
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 274   NaN      0      0         370375   7.7500   NaN        Q
# 86   16.0      1      3     W./C. 6608  34.3750   NaN        S
# 681  27.0      0      0       PC 17572  76.7292   D49        C
# 847  35.0      0      0         349213   7.8958   NaN        C
# 47    NaN      0      0          14311   7.7500   NaN        Q
# 547   NaN      0      0  SC/PARIS 2146  13.8625   NaN        C
# 798  30.0      0      0           2685   7.2292   NaN        C
# 80   22.0      0      0         345767   9.0000   NaN        S
# 221  27.0      0      0         220367  13.0000   NaN        S
# 51   21.0      0      0     A/4. 39886   7.8000   NaN        S

# %% [markdown]
# ## Задание 5
#
# Создайте 2 копии таблицы

# %%
copy1 = table.copy()
copy2 = table.copy()

# %% [markdown]
# ## Задание 6
#
# Выведите информацию о таблице "копия1", выберите столбец с
# пропущенными значениями (они же "null", они же "NaN") и
# удалите их, выведите информацию об этой таблице снова.

# %%
copy1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
copy1 = copy1.dropna(axis=0)

# %%
copy1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ..                                                 ...     ...    ...    ...
# 886                              Montvila, Rev. Juozas    male      0      0
# 887                       Graham, Miss. Margaret Edith  female      0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female      1      2
# 889                              Behr, Mr. Karl Howell    male      0      0
# 890                                Dooley, Mr. Patrick    male      0      0
#
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 9 columns]

# %% [markdown]
# ## Задание 7
#
# Выведите информацию о таблице "копия2", выберите столбец с
# пропущенными значениями (они же "null", они же "NaN") и
# замените их на что-нибудь, выведите информацию об этой
# таблице снова.

# %%
copy2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
copy2 = copy2.fillna('something')

# %%
copy2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male       22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38.0
# 2                               Heikkinen, Miss. Laina  female       26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0
# 4                             Allen, Mr. William Henry    male       35.0
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male       27.0
# 887                       Graham, Miss. Margaret Edith  female       19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  something
# 889                              Behr, Mr. Karl Howell    male       26.0
# 890                                Dooley, Mr. Patrick    male       32.0
#
#      SibSp  Parch            Ticket     Fare      Cabin Embarked
# 0        1      0         A/5 21171   7.2500  something        S
# 1        1      0          PC 17599  71.2833        C85        C
# 2        0      0  STON/O2. 3101282   7.9250  something        S
# 3        1      0            113803  53.1000       C123        S
# 4        0      0            373450   8.0500  something        S
# ..     ...    ...               ...      ...        ...      ...
# 886      0      0            211536  13.0000  something        S
# 887      0      0            112053  30.0000        B42        S
# 888      1      2        W./C. 6607  23.4500  something        S
# 889      0      0            111369  30.0000       C148        C
# 890      0      0            370376   7.7500  something        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Задание 8
#
# В любой таблице выберите столбец с числами и найдите его
# среднее значение.

# %%
numpy.average(copy2.Fare)
# Out:
# 32.204207968574636

# %% [markdown]
# ## Задание 9
#
# В любой таблице выберите столбец с категориальными
# данными (как правило строки) и выведите количество его
# уникальных значений

# %%
unique = copy2.Embarked.unique()
allUnique = ', '.join(map(str, unique))

allUnique
# Out:
# 'S, C, Q, something'

# %% [markdown]
# ## Задание 10
#
# В любой таблице измените значение любой колонки для
# второго и третьего объектов (объект = строка). Выведите
# результаты, что бы убедиться, что изменения сохранились.

# %%
copy2.loc[2:3, 'Ticket'] = ['undefined ticket', 'undefined ticket']

copy2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male       22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38.0
# 2                               Heikkinen, Miss. Laina  female       26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0
# 4                             Allen, Mr. William Henry    male       35.0
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male       27.0
# 887                       Graham, Miss. Margaret Edith  female       19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  something
# 889                              Behr, Mr. Karl Howell    male       26.0
# 890                                Dooley, Mr. Patrick    male       32.0
#
#      SibSp  Parch            Ticket     Fare      Cabin Embarked
# 0        1      0         A/5 21171   7.2500  something        S
# 1        1      0          PC 17599  71.2833        C85        C
# 2        0      0  undefined ticket   7.9250  something        S
# 3        1      0  undefined ticket  53.1000       C123        S
# 4        0      0            373450   8.0500  something        S
# ..     ...    ...               ...      ...        ...      ...
# 886      0      0            211536  13.0000  something        S
# 887      0      0            112053  30.0000        B42        S
# 888      1      2        W./C. 6607  23.4500  something        S
# 889      0      0            111369  30.0000       C148        C
# 890      0      0            370376   7.7500  something        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Задание 11
#
# Cоздайте две маленькие таблицы 3х3 и соедините их в одну.

# %%
table_new1 = pandas.DataFrame(
[
    ['Vasiliy Chernenko',      62,  0],
    ['Nikita Podsolnechnikov', 44,  1],
    ['Vladimir Plecho',        48,  1]
]
)

# %%
table_new2 = pandas.DataFrame(
[
    ['Sergey Abramov',        21,  1],
    ['Michael Drevovidniy',   36,  2],
    ['Leonid Larentyev',      51,  0]
]
)

# %%
table_new = pandas.concat([table_new1, table_new2], ignore_index=True)

table_new
# Out:
#                         0   1  2
# 0       Vasiliy Chernenko  62  0
# 1  Nikita Podsolnechnikov  44  1
# 2         Vladimir Plecho  48  1
# 3          Sergey Abramov  21  1
# 4     Michael Drevovidniy  36  2
# 5        Leonid Larentyev  51  0

# %% [markdown]
# ## Задание 12
#
# Сохраните получившуюся таблицу в формате csv

# %%
table_new.to_csv('table_new.csv')
